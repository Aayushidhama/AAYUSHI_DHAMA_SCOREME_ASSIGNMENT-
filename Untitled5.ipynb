# %%
# !pip install pdfplumber openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 44.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 45.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a2cf9ad-b509-4a92-b5ce-85246bcef441" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a2cf9ad-b509-4a92-b5ce-85246bcef441">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-865f3101-878e-4d9b-9ce2-ec8f322e4981" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-865f3101-878e-4d9b-9ce2-ec8f322e4981">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pdfplumber
import pandas as pd

def extract_tables_from_pdf(file_path):
    tables = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            tables.extend(page.extract_tables())
    return tables

def save_to_excel(tables, output_file):
    for i, table in enumerate(tables):
        if table:  # Check if table is not empty
            df = pd.DataFrame(table[1:], columns=table[0])
            if i == 0:
                with pd.ExcelWriter(output_file) as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
            else:
                with pd.ExcelWriter(output_file, mode='a') as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)

# Example usage
file_path_1 = 'test3.pdf'
output_file_1 = 'output_test3.xlsx'
tables_1 = extract_tables_from_pdf(file_path_1)
save_to_excel(tables_1, output_file_1)

file_path_2 = 'test6.pdf'
output_file_2 = 'output_test6.xlsx'
tables_2 = extract_tables_from_pdf(file_path_2)
save_to_excel(tables_2, output_file_2)

# Download output files
from google.colab import files
files.download(output_file_1)
files.download(output_file_2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-0ef0845a5649> in <cell line: 0>()
#      33 # Download output files
#      34 from google.colab import files
# ---> 35 files.download(output_file_1)
#      36 files.download(output_file_2)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: output_test3.xlsx

# %%
import pdfplumber
import pandas as pd
import os

def extract_tables_from_pdf(file_path):
    tables = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            tables.extend(page.extract_tables())
    return tables

def save_to_excel(tables, output_file):
    for i, table in enumerate(tables):
        if table:  # Check if table is not empty
            df = pd.DataFrame(table[1:], columns=table[0])
            if i == 0:
                # Explicitly specify the path using os.path.join
                with pd.ExcelWriter(os.path.join('.', output_file)) as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
            else:
                # Explicitly specify the path using os.path.join
                with pd.ExcelWriter(os.path.join('.', output_file), mode='a', engine='openpyxl') as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)

# Example usage
file_path_1 = 'test3.pdf'
output_file_1 = 'output_test3.xlsx'

# %%
from google.colab import files
import pandas as pd

# Install required libraries if needed
# !pip install pdfplumber openpyxl

# Upload PDF files
uploaded = files.upload()

# Import pdfplumber after installation
import pdfplumber

def extract_tables_from_pdf(file_path):
    tables = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            tables.extend(page.extract_tables())
    return tables

def save_to_excel(tables, output_file):
    for i, table in enumerate(tables):
        if table:  # Check if table is not empty
            df = pd.DataFrame(table[1:], columns=table[0])
            if i == 0:
                with pd.ExcelWriter(output_file) as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
            else:
                with pd.ExcelWriter(output_file, mode='a') as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)

# Example usage
file_path_1 = 'test3.pdf'
output_file_1 = 'output_test3.xlsx'
tables_1 = extract_tables_from_pdf(file_path_1)
save_to_excel(tables_1, output_file_1)

file_path_2 = 'test6.pdf'
output_file_2 = 'output_test6.xlsx'
tables_2 = extract_tables_from_pdf(file_path_2)
save_to_excel(tables_2, output_file_2)

# Download output files
files.download(output_file_1)
files.download(output_file_2)
# Out:
# ...
#      <input type="file" id="files-d0854ad4-cbbe-4e4b-b0fe-5eeef813f456" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0854ad4-cbbe-4e4b-b0fe-5eeef813f456">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Install required libraries if needed
# !pip install pdfplumber openpyxl

# Import pdfplumber after installation
import pdfplumber

def extract_tables_from_pdf(file_path):
    tables = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            tables.extend(page.extract_tables())
    return tables

def save_to_excel(tables, output_file):
    # Create a new ExcelWriter even if tables is empty to avoid FileNotFoundError
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        for i, table in enumerate(tables):
            if table:  # Check if table is not empty
                df = pd.DataFrame(table[1:], columns=table[0])
                df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
        # Save the Excel file even if it's empty
        writer.save()

# Example usage
file_path_1 = 'test3.pdf'
output_file_1 = 'output_test3.xlsx'
tables_1 = extract_tables_from_pdf(file_path_1)
save_to_excel(tables_1, output_file_1)

file_path_2 = 'test6.pdf'
output_file_2 = 'output_test6.xlsx'
tables_2 = extract_tables_from_pdf(file_path_2)
save_to_excel(tables_2, output_file_2)

# Download output files
files.download(output_file_1)
files.download(output_file_2)
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4af796528df6> in save_to_excel(tables, output_file)
#      24         # Save the Excel file even if it's empty
# ---> 25         writer.save()
#      26
#
# AttributeError: 'OpenpyxlWriter' object has no attribute 'save'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-4af796528df6> in <cell line: 0>()
#      29 output_file_1 = 'output_test3.xlsx'
#      30 tables_1 = extract_tables_from_pdf(file_path_1)
# ---> 31 save_to_excel(tables_1, output_file_1)
#      32
#      33 file_path_2 = 'test6.pdf'
#
# <ipython-input-8-4af796528df6> in save_to_excel(tables, output_file)
#      17 def save_to_excel(tables, output_file):
# ...

# %%
from google.colab import files
import pandas as pd

# Install required libraries if needed
# !pip install pdfplumber openpyxl

# Import pdfplumber after installation
import pdfplumber

def extract_tables_from_pdf(file_path):
    tables = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            tables.extend(page.extract_tables())
    return tables

def save_to_excel(tables, output_file):
    # Create a new ExcelWriter with the openpyxl engine
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        # Check if tables is empty, if so, create an empty DataFrame and add a sheet
        if not tables:
            pd.DataFrame().to_excel(writer, sheet_name='Sheet1', index=False)
        else:
            # If tables is not empty, process as before
            for i, table in enumerate(tables):
                if table:  # Check if table is not empty
                    df = pd.DataFrame(table[1:], columns=table[0])
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
        # Save the Excel file (this is now handled by the with statement)

# Example usage
file_path_1 = 'test3.pdf'
output_file_1 = 'output_test3.xlsx'
tables_1 = extract_tables_from_pdf(file_path_1)
save_to_excel(tables_1, output_file_1)

file_path_2 = 'test6.pdf'
output_file_2 = 'output_test6.xlsx'
tables_2 = extract_tables_from_pdf(file_path_2)
save_to_excel(tables_2, output_file_2)

# Download output files
files.download(output_file_1)
files.download(output_file_2)

# %%
def extract_tables_from_pdf(file_path):
    try:
        tables = []
        with pdfplumber.open(file_path) as pdf:
            for page in pdf.pages:
                extracted_tables = page.extract_tables()
                if extracted_tables:
                    print(f"Extracted {len(extracted_tables)} tables from {file_path}")
                tables.extend(extracted_tables)
        return tables
    except Exception as e:
        print(f"Error extracting tables from {file_path}: {e}")
        return []

# %%
def save_to_excel(tables, output_file):
    try:
        for i, table in enumerate(tables):
            if table:  # Check if table is not empty
                print(f"Table {i+1} has {len(table)} rows and {len(table[0])} columns.")
                df = pd.DataFrame(table[1:], columns=table[0])
                print(df.head())  # Print the first few rows of the DataFrame
                if i == 0:
                    with pd.ExcelWriter(output_file) as writer:
                        df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
                else:
                    with pd.ExcelWriter(output_file, mode='a') as writer:
                        df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
        print(f"Tables saved to {output_file}")
    except Exception as e:
        print(f"Error saving tables to {output_file}: {e}")

# %%
from google.colab import files
import pandas as pd

# Install required libraries if needed
# !pip install pdfplumber openpyxl

# Import pdfplumber after installation
import pdfplumber

# Upload PDF files
uploaded = files.upload()

def extract_tables_from_pdf(file_path):
    try:
        tables = []
        with pdfplumber.open(file_path) as pdf:
            for page in pdf.pages:
                extracted_tables = page.extract_tables(table_settings={"vertical_strategy": "text", "horizontal_strategy": "text"})
                if extracted_tables:
                    print(f"Extracted {len(extracted_tables)} tables from {file_path}")
                tables.extend(extracted_tables)
        return tables
    except Exception as e:
        print(f"Error extracting tables from {file_path}: {e}")
        return []

def save_to_excel(tables, output_file):
    try:
        for i, table in enumerate(tables):
            if table:  # Check if table is not empty
                print(f"Table {i+1} has {len(table)} rows and {len(table[0])} columns.")
                df = pd.DataFrame(table[1:], columns=table[0])
                print(df.head())  # Print the first few rows of the DataFrame
                if i == 0:
                    with pd.ExcelWriter(output_file) as writer:
                        df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
                else:
                    with pd.ExcelWriter(output_file, mode='a') as writer:
                        df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
        print(f"Tables saved to {output_file}")
    except Exception as e:
        print(f"Error saving tables to {output_file}: {e}")

# Example usage
file_path_1 = 'test3.pdf'
output_file_1 = 'output_test3.xlsx'
tables_1 = extract_tables_from_pdf(file_path_1)
if tables_1:
    save_to_excel(tables_1, output_file_1)
else:
    print(f"No tables found in {file_path_1}")

file_path_2 = 'test6.pdf'
output_file_2 = 'output_test6.xlsx'
tables_2 = extract_tables_from_pdf(file_path_2)
if tables_2:
    save_to_excel(tables_2, output_file_2)
else:
    print(f"No tables found in {file_path_2}")

# Download output files
files.download(output_file_1)
files.download(output_file_2)
# Out:
# ...
#      <input type="file" id="files-96686d12-086b-4bfb-b89d-c15225d750ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96686d12-086b-4bfb-b89d-c15225d750ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def extract_tables_from_pdf(file_path):
    tables = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            extracted_tables = page.extract_tables(table_settings={"vertical_strategy": "lines", "horizontal_strategy": "lines"})
            tables.extend(extracted_tables)
    return tables

# %%
test3_tables = extract_tables_from_pdf('test3.pdf')
print(f"Extracted {len(test3_tables)} tables from test3.pdf")

test6_tables = extract_tables_from_pdf('test6.pdf')
print(f"Extracted {len(test6_tables)} tables from test6.pdf")
# Out:
# Extracted 0 tables from test3.pdf
# Extracted 0 tables from test6.pdf

# %%
def save_to_excel(tables, output_file):
    for i, table in enumerate(tables):
        if table:  # Check if table is not empty
            df = pd.DataFrame(table[1:], columns=table[0])
            if i == 0:
                with pd.ExcelWriter(output_file) as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
            else:
                with pd.ExcelWriter(output_file, mode='a') as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)

# Example usage
output_file_1 = 'output_test3.xlsx'
save_to_excel(test3_tables, output_file_1)

output_file_2 = 'output_test6.xlsx'
save_to_excel(test6_tables, output_file_2)

# %%
from google.colab import files
files.download(output_file_1)
files.download(output_file_2)

# %%
from google.colab import files
import pandas as pd

# Install required libraries if needed
# !pip install pdfplumber openpyxl

# Import pdfplumber after installation
import pdfplumber

# Upload PDF files
uploaded = files.upload()

def extract_tables_from_pdf(file_path):
    tables = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            extracted_tables = page.extract_tables(table_settings={"vertical_strategy": "lines", "horizontal_strategy": "lines"})
            tables.extend(extracted_tables)
    return tables

def save_to_excel(tables, output_file):
    for i, table in enumerate(tables):
        if table:  # Check if table is not empty
            df = pd.DataFrame(table[1:], columns=table[0])
            if i == 0:
                with pd.ExcelWriter(output_file) as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)
            else:
                with pd.ExcelWriter(output_file, mode='a') as writer:
                    df.to_excel(writer, sheet_name=f'Table_{i+1}', index=False)

# Example usage
file_path_1 = 'test3.pdf'
output_file_1 = 'output_test3.xlsx'
test3_tables = extract_tables_from_pdf(file_path_1)
print(f"Extracted {len(test3_tables)} tables from {file_path_1}")
if test3_tables:
    save_to_excel(test3_tables, output_file_1)
else:
    print(f"No tables found in {file_path_1}")

file_path_2 = 'test6.pdf'
output_file_2 = 'output_test6.xlsx'
test6_tables = extract_tables_from_pdf(file_path_2)
print(f"Extracted {len(test6_tables)} tables from {file_path_2}")
if test6_tables:
    save_to_excel(test6_tables, output_file_2)
else:
    print(f"No tables found in {file_path_2}")

# Download output files
files.download(output_file_1)
files.download(output_file_2)
# Out:
# ...
#      <input type="file" id="files-083542ff-d114-4de9-9a43-fd5f8ca02c0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-083542ff-d114-4de9-9a43-fd5f8ca02c0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !git config --global user.email "aayushi.dhama.pg23@nsut.ac.in"
# !git config --global user.name "aayushi"
